# %%
rules = """Respeta a los demás. No se permiten insultos ni lenguaje ofensivo. Evita el spam. No publiques enlaces sospechosos o repetitivos. No compartas información personal. Usa los canales adecuados para cada tema. Sigue las instrucciones de los moderadores."""

reglas = rules.split(".")

palabra = input("Introduce una palabra para la búsqueda: ")
ok = False

for elem in reglas:
    if palabra in elem.lower():
        print (elem)
        ok =  True
if (ok == False):
    print ("Ninguna instrucción contenía la palabra que ingresaste")
# Out:
#  No se permiten insultos ni lenguaje ofensivo
#  No publiques enlaces sospechosos o repetitivos
#  No compartas información personal
