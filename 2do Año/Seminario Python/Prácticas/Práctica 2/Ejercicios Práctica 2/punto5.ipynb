# %%
tiempo = int(input ("Ingrese  el tiempo de reacción de un jugador en milisegundos: "))

if tiempo < 200:
    print ("La categoría es Rápido")
elif 200 <= tiempo <= 500:
    print ("La categoría es Normal")
else:
    print ("La categoría es Lento")
# Out:
# La categoría es Lento
