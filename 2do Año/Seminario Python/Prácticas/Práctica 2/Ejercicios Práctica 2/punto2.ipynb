# %%
titles = ["Speedrun de Super Mario en tiempo récord", "Charla sobre desarrollo de videojuegos", "Jugando al nuevo FPS del momento con amigos", "Música en vivo: improvisaciones al piano"]

titulo_mas_largo = max(titles, key=lambda titulo: len(titulo.split()))

print(f"El título con más palabras es: '{titulo_mas_largo}'")

print ("aaaaaaaaaaaaa")
# Out:
# El título con más palabras es: 'Jugando al nuevo FPS del momento con amigos'
# aaaaaaaaaaaaa
